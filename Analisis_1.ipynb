# %% [markdown]
# <a href="https://colab.research.google.com/github/farisea11/Praktikum-OOP-Tugas/blob/main/Analisis_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Hero:
    # Constructor: dijalankan saat Hero baru dibuat
    def __init__(self, name, hp, attack_power):
        self.name = name
        self.hp = hp
        self.attack_power = attack_power

    # Method untuk menampilkan info hero
    def info(self):
        print(f"Hero: {self.name} | HP: {self.hp} | Power: {self.attack_power}")


hero1 = Hero("Layla", 100, 15)
hero2 = Hero("Zilong", 120, 20)

hero1.hp = 500

print(hero1.hp)

hero1.info()
hero2.info()
# Out:
# 500
# Hero: Layla | HP: 500 | Power: 15
# Hero: Zilong | HP: 120 | Power: 20
